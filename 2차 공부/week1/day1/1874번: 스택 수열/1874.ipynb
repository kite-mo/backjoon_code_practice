# %%
import sys

sys.stdin = open('./test.txt')

line_number = int(sys.stdin.readline().rstrip())
real_values = []
for idx, num in enumerate(range(line_number)):    
    line_num = int(sys.stdin.readline().rstrip())
    real_values.append(line_num)

for

# %%
real_values
# Out:
# [4, 3, 6, 8, 7, 5, 2, 1]
