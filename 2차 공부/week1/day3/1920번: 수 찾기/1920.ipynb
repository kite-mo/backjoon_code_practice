# %%
import sys
from collections import deque

sys.stdin = open('/Users/kitemo/코딩테스트/git/backjoon_code_practice/2차 공부/8월/week1/day3/1920번: 수 찾기/test.txt')
N = int(sys.stdin.readline().rstrip())
N_list = set([int(i) for i in sys.stdin.readline().rstrip().split()])
M = int(sys.stdin.readline().rstrip())
M_list = [int(i) for i in sys.stdin.readline().rstrip().split()]

map_dict = {}
for m in M_list:
    inter_set = N_list & set([m])
    if inter_set:
        print(1)
    else:
        print(0)
# Out:
# 1
# 1
# 0
# 0
# 1

# %%
N_list
# Out:
# [1, 2, 3, 4, 5]

# %%
M_list
# Out:
# [1, 3, 7, 9, 5]
